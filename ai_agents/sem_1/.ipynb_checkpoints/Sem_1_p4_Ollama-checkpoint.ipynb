# %% [markdown]
# # Установка и использование Ollama для инференса LLM локально

# %% [markdown]
# Заходим на https://ollama.com/download и скачаиваем клиент

# %% [markdown]
# ![Screenshot 2025-06-18 at 10.46.45.png](data:image/png;base64,...)

# %% [markdown]
# После установки можно пользоваться Ollama:

# %%
! ollama run llama3.2 &
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 3.9 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 185 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 622 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 1.1 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 1.4 MB/2.0 GB                  pulling manifest
# ...

# %% [markdown]
# Список моделей, их версий и код для запуска на вкладке models:

# %% [markdown]
# ![Screenshot 2025-06-18 at 10.55.05.png](data:image/png;base64,...)

# %%
! curl http://localhost:11434/api/tags
# Out:
# {"models":[{"name":"llama3.2:latest","model":"llama3.2:latest","modified_at":"2025-06-18T10:58:53.584446212+03:00","size":2019393189,"digest":"a80c4f17acd55265feec403c7aef86be0c25983ab279d83f3bcd3abbcb5b8b72","details":{"parent_model":"","format":"gguf","family":"llama","families":["llama"],"parameter_size":"3.2B","quantization_level":"Q4_K_M"}}]}

# %%
import requests

response = requests.post(
    "http://localhost:11434/api/generate",
    json={
        "model": "llama3.2",
        "prompt": "О чем сегодня рассказать на курсе?",
        "stream": False
    }
)

print(response.json()["response"])
# Out:
# Сегодня мы можем hablar о чем угодно, что заинтересует или проинтересует आपकих ушей.
#
# Если вы хотите, мы можем рассмотреть разные темы:
#
# 1. Новые новости и события: Мы можем-discuss последние новости, события и trending topics.
# 2. РазвLEARNING: Мы можем parler о различных областях, таких как информатика, научная литература, или даже о личных увлечениях.
# 3. Культурные темы: Мы можем обсуждать культуру, музыку, кино, books и andere интересующие вас темы.
#
# Они что-никак-не важны для меня, я просто готов поделиться с вами своей знаниями и опыта.

# %% [markdown]
# ## Ура! Мы получаем ответ через API от модели, развернутой локально
